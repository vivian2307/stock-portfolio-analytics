# %%
import pandas as pd
import requests
import json

# %%
import pandas as pd
import requests

api_key = 'co71nohr01qj6a5mhrg0co71nohr01qj6a5mhrgg'

# Xây dựng URL cho yêu cầu API
url = f'https://finnhub.io/api/v1/stock/symbol?exchange=US&token={api_key}'

# Gửi yêu cầu API và nhận dữ liệu
response = requests.get(url)

if response.status_code == 200:
    data = response.json()

    stock_data = [item for item in data if item['mic'] == 'XNAS']
    df = pd.DataFrame(stock_data)

    print("DataFrame chứa thông tin cổ phiếu trên sàn NASDAQ:")
    print(df)
else:
    print("Yêu cầu thất bại")
# Out:
# DataFrame chứa thông tin cổ phiếu trên sàn NASDAQ:
#      currency                   description displaySymbol          figi  isin  \
# 0         USD             LAM RESEARCH CORP          LRCX  BBG000BNFLM9  None
# 1         USD         LEMAITRE VASCULAR INC          LMAT  BBG000LY1HS2  None
# 2         USD    ACADIA PHARMACEUTICALS INC          ACAD  BBG000BHG9K0  None
# 3         USD  NRX PHARMACEUTICALS INC-CW22         NRXPW  BBG00JCWDKV1  None
# 4         USD             SOUNDTHINKING INC          SSTI  BBG000Q1PX08  None
# ...       ...                           ...           ...           ...   ...
# 4923      USD         LYRA THERAPEUTICS INC          LYRA  BBG001J2N202  None
# 4924      USD   CHINA NATURAL RESOURCES INC          CHNR  BBG000BX3NJ0  None
# 4925      USD         BENEFICIENT - CLASS A          BENF  BBG00KFV0B41  None
# 4926      USD        THIRD HARMONIC BIO INC          THRD  BBG00Z14GXB0  None
# 4927      USD        VENTYX BIOSCIENCES INC          VTYX  BBG00VC84K29  None
#
#        mic shareClassFIGI symbol symbol2          type
# 0     XNAS   BBG001S5SW40   LRCX          Common Stock
# 1     XNAS   BBG001SK6CX3   LMAT          Common Stock
# 2     XNAS   BBG001SB06N3   ACAD          Common Stock
# 3     XNAS                 NRXPW            Equity WRT
# 4     XNAS   BBG001SM2GR1   SSTI          Common Stock
# ...    ...            ...    ...     ...           ...
# 4923  XNAS   BBG001V0GBW5   LYRA          Common Stock
# 4924  XNAS   BBG001S79DX7   CHNR          Common Stock
# 4925  XNAS   BBG00KFV0B50   BENF          Common Stock
# 4926  XNAS   BBG00Z14GXC9   THRD          Common Stock
# 4927  XNAS   BBG00VC84K47   VTYX          Common Stock
#
# [4928 rows x 10 columns]

# %%
df = pd.DataFrame(stock_data)
print(df)
# Out:
#      currency                   description displaySymbol          figi  isin  \
# 0         USD             LAM RESEARCH CORP          LRCX  BBG000BNFLM9  None
# 1         USD         LEMAITRE VASCULAR INC          LMAT  BBG000LY1HS2  None
# 2         USD    ACADIA PHARMACEUTICALS INC          ACAD  BBG000BHG9K0  None
# 3         USD  NRX PHARMACEUTICALS INC-CW22         NRXPW  BBG00JCWDKV1  None
# 4         USD             SOUNDTHINKING INC          SSTI  BBG000Q1PX08  None
# ...       ...                           ...           ...           ...   ...
# 4923      USD         LYRA THERAPEUTICS INC          LYRA  BBG001J2N202  None
# 4924      USD   CHINA NATURAL RESOURCES INC          CHNR  BBG000BX3NJ0  None
# 4925      USD         BENEFICIENT - CLASS A          BENF  BBG00KFV0B41  None
# 4926      USD        THIRD HARMONIC BIO INC          THRD  BBG00Z14GXB0  None
# 4927      USD        VENTYX BIOSCIENCES INC          VTYX  BBG00VC84K29  None
#
#        mic shareClassFIGI symbol symbol2          type
# 0     XNAS   BBG001S5SW40   LRCX          Common Stock
# 1     XNAS   BBG001SK6CX3   LMAT          Common Stock
# 2     XNAS   BBG001SB06N3   ACAD          Common Stock
# 3     XNAS                 NRXPW            Equity WRT
# 4     XNAS   BBG001SM2GR1   SSTI          Common Stock
# ...    ...            ...    ...     ...           ...
# 4923  XNAS   BBG001V0GBW5   LYRA          Common Stock
# 4924  XNAS   BBG001S79DX7   CHNR          Common Stock
# 4925  XNAS   BBG00KFV0B50   BENF          Common Stock
# 4926  XNAS   BBG00Z14GXC9   THRD          Common Stock
# 4927  XNAS   BBG00VC84K47   VTYX          Common Stock
#
# [4928 rows x 10 columns]

# %%
print(df.head())
# Out:
#   currency                   description displaySymbol          figi  isin  \
# 0      USD             LAM RESEARCH CORP          LRCX  BBG000BNFLM9  None
# 1      USD         LEMAITRE VASCULAR INC          LMAT  BBG000LY1HS2  None
# 2      USD    ACADIA PHARMACEUTICALS INC          ACAD  BBG000BHG9K0  None
# 3      USD  NRX PHARMACEUTICALS INC-CW22         NRXPW  BBG00JCWDKV1  None
# 4      USD             SOUNDTHINKING INC          SSTI  BBG000Q1PX08  None
#
#     mic shareClassFIGI symbol symbol2          type
# 0  XNAS   BBG001S5SW40   LRCX          Common Stock
# 1  XNAS   BBG001SK6CX3   LMAT          Common Stock
# 2  XNAS   BBG001SB06N3   ACAD          Common Stock
# 3  XNAS                 NRXPW            Equity WRT
# 4  XNAS   BBG001SM2GR1   SSTI          Common Stock

# %%
from IPython.display import display
pd.set_option('display.notebook_repr_html', True)
# Hiển thị DataFrame dưới dạng bảng
display(df)
# Out:
#      currency                   description displaySymbol          figi  isin  \
# 0         USD             LAM RESEARCH CORP          LRCX  BBG000BNFLM9  None
# 1         USD         LEMAITRE VASCULAR INC          LMAT  BBG000LY1HS2  None
# 2         USD    ACADIA PHARMACEUTICALS INC          ACAD  BBG000BHG9K0  None
# 3         USD  NRX PHARMACEUTICALS INC-CW22         NRXPW  BBG00JCWDKV1  None
# 4         USD             SOUNDTHINKING INC          SSTI  BBG000Q1PX08  None
# ...       ...                           ...           ...           ...   ...
# 4923      USD         LYRA THERAPEUTICS INC          LYRA  BBG001J2N202  None
# 4924      USD   CHINA NATURAL RESOURCES INC          CHNR  BBG000BX3NJ0  None
# 4925      USD         BENEFICIENT - CLASS A          BENF  BBG00KFV0B41  None
# 4926      USD        THIRD HARMONIC BIO INC          THRD  BBG00Z14GXB0  None
# 4927      USD        VENTYX BIOSCIENCES INC          VTYX  BBG00VC84K29  None
#
#        mic shareClassFIGI symbol symbol2          type
# 0     XNAS   BBG001S5SW40   LRCX          Common Stock
# 1     XNAS   BBG001SK6CX3   LMAT          Common Stock
# 2     XNAS   BBG001SB06N3   ACAD          Common Stock
# 3     XNAS                 NRXPW            Equity WRT
# 4     XNAS   BBG001SM2GR1   SSTI          Common Stock
# ...    ...            ...    ...     ...           ...
# 4923  XNAS   BBG001V0GBW5   LYRA          Common Stock
# 4924  XNAS   BBG001S79DX7   CHNR          Common Stock
# 4925  XNAS   BBG00KFV0B50   BENF          Common Stock
# 4926  XNAS   BBG00Z14GXC9   THRD          Common Stock
# 4927  XNAS   BBG00VC84K47   VTYX          Common Stock
#
# [4928 rows x 10 columns]

# %%
display(df)
# Out:
#      currency                   description displaySymbol          figi  isin  \
# 0         USD             LAM RESEARCH CORP          LRCX  BBG000BNFLM9  None
# 1         USD         LEMAITRE VASCULAR INC          LMAT  BBG000LY1HS2  None
# 2         USD    ACADIA PHARMACEUTICALS INC          ACAD  BBG000BHG9K0  None
# 3         USD  NRX PHARMACEUTICALS INC-CW22         NRXPW  BBG00JCWDKV1  None
# 4         USD             SOUNDTHINKING INC          SSTI  BBG000Q1PX08  None
# ...       ...                           ...           ...           ...   ...
# 4923      USD         LYRA THERAPEUTICS INC          LYRA  BBG001J2N202  None
# 4924      USD   CHINA NATURAL RESOURCES INC          CHNR  BBG000BX3NJ0  None
# 4925      USD         BENEFICIENT - CLASS A          BENF  BBG00KFV0B41  None
# 4926      USD        THIRD HARMONIC BIO INC          THRD  BBG00Z14GXB0  None
# 4927      USD        VENTYX BIOSCIENCES INC          VTYX  BBG00VC84K29  None
#
#        mic shareClassFIGI symbol symbol2          type
# 0     XNAS   BBG001S5SW40   LRCX          Common Stock
# 1     XNAS   BBG001SK6CX3   LMAT          Common Stock
# 2     XNAS   BBG001SB06N3   ACAD          Common Stock
# 3     XNAS                 NRXPW            Equity WRT
# 4     XNAS   BBG001SM2GR1   SSTI          Common Stock
# ...    ...            ...    ...     ...           ...
# 4923  XNAS   BBG001V0GBW5   LYRA          Common Stock
# 4924  XNAS   BBG001S79DX7   CHNR          Common Stock
# 4925  XNAS   BBG00KFV0B50   BENF          Common Stock
# 4926  XNAS   BBG00Z14GXC9   THRD          Common Stock
# 4927  XNAS   BBG00VC84K47   VTYX          Common Stock
#
# [4928 rows x 10 columns]

# %%
df.columns
# Out:
# Index(['currency', 'description', 'displaySymbol', 'figi', 'isin', 'mic',
#        'shareClassFIGI', 'symbol', 'symbol2', 'type'],
#       dtype='object')

# %%
# Using square brackets notation
symbol_column = df['symbol']

# Using dot notation (if the column name doesn't have spaces or special characters)
symbol_column = df.symbol
print(symbol_column)
# Out:
# 0        LRCX
# 1        LMAT
# 2        ACAD
# 3       NRXPW
# 4        SSTI
#         ...
# 4923     LYRA
# 4924     CHNR
# 4925     BENF
# 4926     THRD
# 4927     VTYX
# Name: symbol, Length: 4928, dtype: object

# %%
top_5_symbols = df['symbol'].value_counts().head(5)
print(top_5_symbols)
# Out:
# symbol
# LRCX    1
# LRE     1
# ICCC    1
# PRDO    1
# DNLI    1
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# currency             0
# description          0
# displaySymbol        0
# figi                 0
# isin              4928
# mic                  0
# shareClassFIGI       0
# symbol               0
# symbol2              0
# type                 0
# dtype: int64

# %%
df.shape
# Out:
# (4928, 10)

# %%
df.drop_duplicates(inplace=True)

# %%
df.head()
# Out:
#   currency                   description displaySymbol          figi  isin  \
# 0      USD             LAM RESEARCH CORP          LRCX  BBG000BNFLM9  None
# 1      USD         LEMAITRE VASCULAR INC          LMAT  BBG000LY1HS2  None
# 2      USD    ACADIA PHARMACEUTICALS INC          ACAD  BBG000BHG9K0  None
# 3      USD  NRX PHARMACEUTICALS INC-CW22         NRXPW  BBG00JCWDKV1  None
# 4      USD             SOUNDTHINKING INC          SSTI  BBG000Q1PX08  None
#
#     mic shareClassFIGI symbol symbol2          type
# 0  XNAS   BBG001S5SW40   LRCX          Common Stock
# 1  XNAS   BBG001SK6CX3   LMAT          Common Stock
# 2  XNAS   BBG001SB06N3   ACAD          Common Stock
# 3  XNAS                 NRXPW            Equity WRT
# 4  XNAS   BBG001SM2GR1   SSTI          Common Stock

# %%
df.shape
# Out:
# (4928, 10)

# %%
# Xuất DataFrame ra file Excel
df.to_excel('Stock_description_xnas.xlsx', index=False)

# %%
# Tìm ra các giá trị duy nhất trong cột "type"
unique_values = df['type'].unique()

value_counts = df['type'].value_counts()

print("Các giá trị duy nhất trong cột 'type':")
print(unique_values)
print("\nSố lần xuất hiện của mỗi giá trị:")
print(value_counts)
# Out:
# Các giá trị duy nhất trong cột 'type':
# ['Common Stock' 'Equity WRT' 'ETP' 'Right' 'Tracking Stk' 'PUBLIC' 'ADR'
#  'Unit' 'REIT' '' 'Closed-End Fund' 'Royalty Trst' 'MLP' 'NY Reg Shrs'
#  'Ltd Part']
#
# Số lần xuất hiện của mỗi giá trị:
# type
# Common Stock       3147
# ETP                 620
# Equity WRT          455
# ADR                 200
# PUBLIC              187
# Unit                163
# Right                61
#                      36
# REIT                 28
# Closed-End Fund      14
# Tracking Stk          7
# MLP                   7
# Royalty Trst          1
# NY Reg Shrs           1
# Ltd Part              1
# Name: count, dtype: int64
